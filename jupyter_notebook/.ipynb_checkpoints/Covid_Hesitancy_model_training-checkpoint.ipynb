# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Setting up data
# ___
#
# Our goal here is to merge two datasets. One for deaths per county, and our covid vaccine hesitancy dataset.

# %%
covid_data = pd.read_csv("data/Vaccine_Hesitancy.csv")
# covid_data.isnull().sum() # Check for missing values
deaths = pd.read_csv("data/COVID_Deaths.csv")
#deaths.isnull().sum() # Check for missing values

# make a new column (percentage of deaths involving covid-19)
deaths["Percent deaths involving COVID"] = deaths["Deaths involving COVID-19"] / deaths["Deaths from All Causes"]

# %%
# combine deaths and hesitancy horizontally, but lining up based on county
hesitancy_deaths_data = deaths.merge(covid_data, left_on="FIPS County Code", 
                      right_on="FIPS_Code", how = 'inner')

# %%
# make a new column adding up the percentage of people who are hesitant
hesitancy_deaths_data['Percent Hesitant'] = covid_data['Estimated_hesitant'] + covid_data['Estimated_hesitant_or_unsure'] + covid_data['Estimated_strongly_hesitant']

# %%
hesitancy_deaths_data.head(2)
# Out:
#   State_x             County name  FIPS County Code Urban Rural Code  \
# 0      AK  Anchorage Municipality              2020     Medium metro
# 1      AK      Bethel Census Area              2050          Noncore
#
#    Deaths involving COVID-19  Deaths from All Causes  \
# 0                      204.0                  3143.0
# 1                       17.0                   154.0
#
#    Percent deaths involving COVID  FIPS_Code                     County_Name  \
# 0                        0.064906       2020  Anchorage Municipality, Alaska
# 1                        0.110390       2050      Bethel Census Area, Alaska
#
#   State_y  ...  Percent_vaccinated  Percent_Hispanic  Percent_Native  \
# 0  ALASKA  ...               0.542            0.0917          0.0737
# 1  ALASKA  ...               0.689            0.0260          0.8250
#
#    Percent_Asian Percent_Black  Percent_Hawaiian Percent_White  \
# 0         0.0943        0.0528            0.0241        0.5790
# 1         0.0108        0.0074            0.0022        0.0973
#
#         Geographical_Point  State_Code  Percent Hesitant
# 0  (-151.631889 63.631126)          AK            0.5589
# 1  (-151.631889 63.631126)          AK            0.5501
#
# [2 rows x 27 columns]

# %% [markdown]
# We are going to add a new collumn below to use the new total hesitant values that way we can group them up into categories that we can later explore with categorization models

# %%
total_hesitancy = hesitancy_deaths_data['Percent Hesitant']
# extreme risk  > 0.6
# high concern  0.4 - 0.6 
# low risk < 0.4
# no risk -> needed to use list comprehension code, but this category can never be met
hesitancy_deaths_data["hesitancy_categories"] = ["extreme risk" if value >= 0.5 else "high risk" if value >= 0.4 else "low risk" if value < 0.4 else "no risk" for value in total_hesitancy]

# %%
## We can use this piece of code to filter counties with a high risk for lack in vaccinations 
hesitancy_deaths_data.loc[hesitancy_deaths_data["hesitancy_categories"] == "high risk"].head(3)
# Out:
#    State_x      County name  FIPS County Code    Urban Rural Code  \
# 12      AL  Chambers County              1017        Micropolitan
# 14      AL   Chilton County              1021  Large fringe metro
# 19      AL    Coffee County              1031        Micropolitan
#
#     Deaths involving COVID-19  Deaths from All Causes  \
# 12                       39.0                   570.0
# 14                       32.0                   622.0
# 19                       87.0                   854.0
#
#     Percent deaths involving COVID  FIPS_Code               County_Name  \
# 12                        0.068421       1017  Chambers County, Alabama
# 14                        0.051447       1021   Chilton County, Alabama
# 19                        0.101874       1031    Coffee County, Alabama
#
#     State_y  ...  Percent_Hispanic  Percent_Native  Percent_Asian  \
# 12  ALABAMA  ...            0.0238          0.0033         0.0112
# 14  ALABAMA  ...            0.0785          0.0009         0.0044
# 19  ALABAMA  ...            0.0728          0.0116         0.0144
#
#     Percent_Black Percent_Hawaiian  Percent_White      Geographical_Point  \
# 12         0.3956              0.0         0.5555  (-86.844516 32.756889)
# 14         0.0917              0.0         0.8013  (-86.844516 32.756889)
# 19         0.1680              0.0         0.7015  (-86.844516 32.756889)
#
#     State_Code  Percent Hesitant  hesitancy_categories
# 12          AL            0.4839             high risk
# 14          AL            0.4597             high risk
# 19          AL            0.4695             high risk
#
# [3 rows x 28 columns]

# %%
ax = hesitancy_deaths_data.hist(column='Percent deaths involving COVID', bins=25, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)

# %%
# 0 - 0.06 --> low
# 0.06 - 0.09 --> medium
# 0.09 - 0.13 --> medium high
# 0.13 - up --> high

death_categories = []
for percent in hesitancy_deaths_data["Percent deaths involving COVID"]:
    if percent >= 0.1:
        death_categories.append("high percentage")
    elif percent >= 0.05: 
        death_categories.append("medium percentage")
    else: 
        death_categories.append("low percentage")

hesitancy_deaths_data["death_categories"] = death_categories
hesitancy_deaths_data

# hesitancy_deaths_data["death_categories"] = ["high percentage" if value >= 0.13 else "medium high percentage" if value >= 0.09 else "medium percentage" if value < 0.06 else "no percentage" for value in hesitancy_deaths_data['Percent deaths involving COVID']]
# Out:
#      State_x                   County name  FIPS County Code Urban Rural Code  \
# 0         AK        Anchorage Municipality              2020     Medium metro
# 1         AK            Bethel Census Area              2050          Noncore
# 2         AK  Fairbanks North Star Borough              2090      Small metro
# 3         AK       Kenai Peninsula Borough              2122          Noncore
# 4         AK     Matanuska-Susitna Borough              2170     Medium metro
# ...      ...                           ...               ...              ...
# 2128      WY                Natrona County             56025      Small metro
# 2129      WY                   Park County             56029          Noncore
# 2130      WY               Sheridan County             56033     Micropolitan
# 2131      WY             Sweetwater County             56037     Micropolitan
# 2132      WY               Washakie County             56043          Noncore
#
#       Deaths involving COVID-19  Deaths from All Causes  \
# 0                         204.0                  3143.0
# 1                          17.0                   154.0
# 2                          47.0                   741.0
# 3                          14.0                   501.0
# 4                          47.0                   873.0
# ...                         ...                     ...
# 2128                      190.0                  1607.0
# 2129                       28.0                   469.0
# 2130                       33.0                   489.0
# 2131                       40.0                   516.0
# 2132                       20.0                   135.0
#
#       Percent deaths involving COVID  FIPS_Code  \
# 0                           0.064906       2020
# 1                           0.110390       2050
# 2                           0.063428       2090
# 3                           0.027944       2122
# 4                           0.053837       2170
# ...                              ...        ...
# 2128                        0.118233      56025
# 2129                        0.059701      56029
# 2130                        0.067485      56033
# 2131                        0.077519      56037
# 2132                        0.148148      56043
#
#                                County_Name  State_y  ...  Percent_Native  \
# 0           Anchorage Municipality, Alaska   ALASKA  ...          0.0737
# 1               Bethel Census Area, Alaska   ALASKA  ...          0.8250
# 2     Fairbanks North Star Borough, Alaska   ALASKA  ...          0.0727
# 3          Kenai Peninsula Borough, Alaska   ALASKA  ...          0.0772
# 4        Matanuska-Susitna Borough, Alaska   ALASKA  ...          0.0604
# ...                                    ...      ...  ...             ...
# 2128               Natrona County, Wyoming  WYOMING  ...          0.0098
# 2129                  Park County, Wyoming  WYOMING  ...          0.0046
# 2130              Sheridan County, Wyoming  WYOMING  ...          0.0179
# 2131            Sweetwater County, Wyoming  WYOMING  ...          0.0102
# 2132              Washakie County, Wyoming  WYOMING  ...          0.0052
#
#       Percent_Asian  Percent_Black  Percent_Hawaiian Percent_White  \
# 0            0.0943         0.0528            0.0241        0.5790
# 1            0.0108         0.0074            0.0022        0.0973
# 2            0.0309         0.0428            0.0051        0.6993
# 3            0.0157         0.0054            0.0033        0.7992
# 4            0.0137         0.0115            0.0022        0.7922
# ...             ...            ...               ...           ...
# 2128         0.0058         0.0108            0.0017        0.8669
# 2129         0.0053         0.0067            0.0000        0.9105
# 2130         0.0067         0.0022            0.0000        0.9168
# 2131         0.0074         0.0112            0.0003        0.7956
# 2132         0.0000         0.0004            0.0000        0.8190
#
#            Geographical_Point State_Code  Percent Hesitant  \
# 0     (-151.631889 63.631126)         AK            0.5589
# 1     (-151.631889 63.631126)         AK            0.5501
# 2     (-151.631889 63.631126)         AK            0.5429
# 3     (-151.631889 63.631126)         AK            0.5429
# 4     (-151.631889 63.631126)         AK            0.5497
# ...                       ...        ...               ...
# 2128   (-107.55145 42.999627)         WY            0.5706
# 2129   (-107.55145 42.999627)         WY            0.3391
# 2130   (-107.55145 42.999627)         WY            0.6211
# 2131   (-107.55145 42.999627)         WY            0.4744
# 2132   (-107.55145 42.999627)         WY            0.5978
#
#       hesitancy_categories   death_categories
# 0             extreme risk  medium percentage
# 1             extreme risk    high percentage
# 2             extreme risk  medium percentage
# 3             extreme risk     low percentage
# 4             extreme risk  medium percentage
# ...                    ...                ...
# 2128          extreme risk    high percentage
# 2129              low risk  medium percentage
# 2130          extreme risk  medium percentage
# 2131             high risk  medium percentage
# 2132          extreme risk    high percentage
#
# [2133 rows x 29 columns]

# %% [markdown]
# # Model training

# %%
from sklearn.model_selection import train_test_split
from joblib import dump, load

# %% [markdown]
# ## Failed Linear regression training
# ___
# This test is a linear regression model between:
#
# input: **Percent hesitant**
#
# output: **Percent of COVID related deaths**

# %%
from sklearn.linear_model import LinearRegression
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
X = hesitancy_deaths_data["CVAC_vloc"]
y = hesitancy_deaths_data["Deaths involving COVID-19"]

# %%
# Splitting the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#reshape data for regression (needs to be a 1D array)
X_train= X_train.values.reshape(-1, 1)
y_train= y_train.values.reshape(-1, 1)
X_test = X_test.values.reshape(-1, 1)
y_test = y_test.values.reshape(-1, 1)

# %%
# Create linear regression object
model = linear_model.LinearRegression()

# Train the model using the training sets
model.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = model.predict(X_test)

# %% [markdown]
# ### Results

# %%
# The coefficients
print('Coefficients: \n', model.coef_)

# The mean squared error
print('Mean squared error: {0:.4f}'.format(mean_squared_error(y_test, y_pred, squared=True)))

# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.4f' %r2_score(y_test, y_pred))

# Plot outputs
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=3)

#plt.xticks(())
#plt.yticks(())

plt.show()

#Save the model
# joblib.dump(model, 'linear_reg_model,joblib')
# Out:
# Coefficients:
#  [[-159.06166855]]
# Mean squared error: 278773.0159
# Coefficient of determination: -0.0070

# %% [markdown]
# ## Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn import tree 

# visualizing tree
from IPython.display import Image  
from sklearn.tree import export_graphviz
from dtreeviz.trees import dtreeviz

# %%
# independent variables (should we use SVI and CVAC)
feature_cols = ['CVAC_vloc', 'SVI', 'Percent Hesitant']
X = hesitancy_deaths_data[feature_cols]
y = hesitancy_deaths_data['death_categories']

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1) # 80% training and 20% test

# %%
# Create Decision Tree classifer object
clf = DecisionTreeClassifier(max_depth=3)

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

# Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5152224824355972

# %%
# tree.export_graphviz(clf, out_file="decision_tree.dot",  
#                 filled=True, rounded=True,
#                 special_characters=True, feature_names = feature_cols,class_names=y.unique())
# viz = dtreeviz(clf, X, y, target_name='target', feature_names = feature_cols)

# %%
# plot tree
plt.figure(figsize=(12,12))  # set plot size (denoted in inches)
tree.plot_tree(clf,
               feature_names = feature_cols, 
               class_names=y.unique(),
               rounded=True, 
               filled = True);
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from itertools import repeat
import scipy.stats

p_data = y.value_counts(normalize=True)           # counts occurrence of each value
entropy = scipy.stats.entropy(p_data)  # get entropy from counts

# %%
avg_score = 0.0
ntimes = 30

for i in repeat(None, ntimes):

    # train model with 80% of the data
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

    # prediction
    model = DecisionTreeClassifier(criterion='entropy')
    model.fit(X_train,y_train)
    predictions = model.predict(X_test)

    # compute model accuracy
    avg_score += accuracy_score(y_test, predictions)

avg_score /= ntimes

# %%
print('entropy: %.3f'% entropy)
print('average accuracy score: %.3f' % avg_score)
# Out:
# entropy: 0.968
# average accuracy score: 0.437
